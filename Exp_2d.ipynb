# %%
import pandas as pd

# 1. Read data
text_df = pd.read_csv('Google_data (2b.c1).csv')
excel_df = pd.read_excel('data (2c2).xlsx', sheet_name='Sheet1')
web_df = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv')

# 2. Display initial rows
print("Text Data:")
print(text_df.head(), "\n")

print("Excel Data:")
print(excel_df.head(), "\n")

print("Web Data:")
print(web_df.head(), "\n")

# 3. Handle missing values (Updated for Pandas 2.0+)
text_df = text_df.ffill()
excel_df = excel_df.bfill()
web_df.dropna(inplace=True)

# 4. Save processed data
text_df.to_csv('processed_text.csv', index=False)
excel_df.to_excel('processed_excel.xlsx', index=False)
# Out:
# Text Data:
#     ID     Name Department   Age   Salary       City
# 0  101    Alice         HR  25.0  35000.0    Chennai
# 1  102      Bob         IT  30.0  50000.0  Bengaluru
# 2  103  Charlie    Finance  28.0  45000.0  Hyderabad
# 3  104    David         IT   NaN  55000.0     Mumbai
# 4  105      Eva  Marketing  26.0      NaN      Delhi
#
# Excel Data:
#    Employee_ID    Name Department      Age   Salary Experience
# 0          201    Arun         IT       24    45000          2
# 1          202   Beena         HR       29    52000          5
# 2          203  Charan    Finance       31    61000          7
# 3          204   Divya         IT  (blank)    58000          6
# 4          205    Esha  Marketing       26  (blank)          3
#
# Web Data:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA
